# %% [markdown]
# <a href="https://colab.research.google.com/github/simsang1l/python_workshop/blob/main/2023summer/Day2/04_Function%2C%20Iteration%20/ls11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [raw]
# ---
# title: "Lesson 11: groupby"
# author: "최규빈"
# date: "07/25/2023"
# ---

# %% [markdown]
# <a href="https://colab.research.google.com/github/guebin/PP2023SUM/blob/main/posts/Day2/04_Function, Iteration/ls11.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" style="text-align: left"></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # df.groupby

# %% [markdown]
# `-` 예제1: 아래의 예제에서 그룹별 평균을 구하여라.

# %%
_category = ['A']*5+['B']*5
_value = np.concatenate([np.random.randn(5), np.random.randn(5)+10])
df = pd.DataFrame({'category':_category, 'value':_value})
df
# Out:
#   category      value
# 0        A  -1.115880
# 1        A   1.109800
# 2        A   0.364589
# 3        A   0.518465
# 4        A   1.571603
# 5        B   8.883637
# 6        B  12.943322
# 7        B   8.463850
# 8        B  10.164719
# 9        B  10.685973

# %% [markdown]
# `-` 방법1: groupby를 이용하지 않는 방법들

# %%
# 이렇게 해도 되고
df[df.category == 'A'].value.mean(), df[df.category == 'B'].value.mean()
# Out:
# (0.4897153568753304, 10.228300113047595)

# %%
# 이것도 가능
{s:df[df.category == s].value.mean() for s in set(df.category)}
# Out:
# {'A': 0.4897153568753304, 'B': 10.228300113047595}

# %% [markdown]
# `-` 방법2: groupby만 사용

# %%
grouped_list = list(df.groupby('category'))
grouped_list
# Out:
# [('A',
#     category     value
#   0        A -1.115880
#   1        A  1.109800
#   2        A  0.364589
#   3        A  0.518465
#   4        A  1.571603),
#  ('B',
#     category      value
#   5        B   8.883637
#   6        B  12.943322
#   7        B   8.463850
#   8        B  10.164719
#   9        B  10.685973)]

# %%
bundle1, bundle2 = grouped_list

# %%
group_name1, sub_df1 = bundle1

# %%
display(sub_df1)
# Out:
#   category     value
# 0        A -1.115880
# 1        A  1.109800
# 2        A  0.364589
# 3        A  0.518465
# 4        A  1.571603

# %%
for group_name, sub_df in df.groupby('category'):
    print(group_name)
    display(sub_df)
# Out:
# A
#   category     value
# 0        A -1.115880
# 1        A  1.109800
# 2        A  0.364589
# 3        A  0.518465
# 4        A  1.571603
# B
#   category      value
# 5        B   8.883637
# 6        B  12.943322
# 7        B   8.463850
# 8        B  10.164719
# 9        B  10.685973

# %%
{group_name:sub_df.value.mean() for group_name, sub_df in df.groupby('category')}
# Out:
# {'A': 0.4897153568753304, 'B': 10.228300113047595}

# %% [markdown]
# `-` 방법3: groupby().aggregate()

# %%
grouped = df.groupby('category')
grouped.aggregate(np.mean)
# Out:
#               value
# category
# A          0.489715
# B         10.228300

# %%
df.groupby(['category']).aggregate(np.mean)
# Out:
#               value
# category
# A          0.489715
# B         10.228300

# %% [markdown]
# ***groupby(?)에서 올 수 있는 구조***
#
# - 열의이름
# - [열의이름,열의이름]

# %% [markdown]
# ***aggregate(?)에서 올 수 있는 구조***
#
# - 함수: 함수자체^[np.mean,sum]가 오거나, 함수를 의미하는 문자열^['size', 'count', 'sum', 'mean', 'median', 'min', 'max', 'std', 'var'] 이 올 수 있음.
# - 리스트: [함수, 함수] # 여기에서 함수자리에는 함수자체, 혹은 함수문자열 아무것이나 올 수 있음.
# - 딕셔너리1: {열의이름:함수}
# - 딕셔너리2: {열의이름:[함수,함수]}

# %%
df.groupby(['category']).aggregate({'value':[np.mean,'size']})
# Out:
#               value
#                mean size
# category
# A          0.489715    5
# B         10.228300    5

# %% [markdown]
# # pd.cut + df.groupby

# %% [markdown]
# `-` 구간별 count

# %%
arr = np.random.rand(1000)

# %%
_bin = [0, 0.2, 0.5, 0.9, 1]
_bin
# Out:
# [0, 0.2, 0.5, 0.9, 1]

# %% [markdown]
# `-` [0,0.2,0.5,0.9,1] 구간에 몇개의 숫자들이 있는지 알고 싶고, 구간별 평균도 알고싶다.

# %%
pd.DataFrame({'cat':pd.cut(arr,_bin), 'arr':arr}).groupby('cat').aggregate({'arr':['size',np.mean]})
# Out:
#             arr
#            size      mean
# cat
# (0.0, 0.2]  189  0.099927
# (0.2, 0.5]  309  0.356922
# (0.5, 0.9]  407  0.702618
# (0.9, 1.0]   95  0.949145

# %% [markdown]
# # flights data

# %%
df=pd.read_csv('https://raw.githubusercontent.com/PacktPublishing/Pandas-Cookbook/master/data/flights.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58492 entries, 0 to 58491
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MONTH      58492 non-null  int64
#  1   DAY        58492 non-null  int64
#  2   WEEKDAY    58492 non-null  int64
#  3   AIRLINE    58492 non-null  object
#  4   ORG_AIR    58492 non-null  object
#  5   DEST_AIR   58492 non-null  object
#  6   SCHED_DEP  58492 non-null  int64
#  7   DEP_DELAY  57659 non-null  float64
#  8   AIR_TIME   57474 non-null  float64
#  9   DIST       58492 non-null  int64
#  10  SCHED_ARR  58492 non-null  int64
#  11  ARR_DELAY  57474 non-null  float64
#  12  DIVERTED   58492 non-null  int64
#  13  CANCELLED  58492 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 6.2+ MB

# %% [markdown]
# `-` 예제1: 항공사(AIRLINE)별로 도착지연시간의(ARR_DELAY)의 평균을 구하라.

# %%
df.groupby('AIRLINE').aggregate({'ARR_DELAY':'mean'})
# Out:
#          ARR_DELAY
# AIRLINE
# AA        5.542661
# AS       -0.833333
# B6        8.692593
# DL        0.339691
# EV        7.034580
# F9       13.630651
# HA        4.972973
# MQ        6.860591
# NK       18.436070
# OO        7.593463
# UA        7.765755
# US        1.681105
# VX        5.348884
# WN        6.397353

# %% [markdown]
# `-` 예제2: 항공사(AIRLINE)별로 비행취소건수(CANCELLED)의 합계를 구하라. 취소건수가 가장 높은 두개의 항공사는 어디인가?

# %%
df.groupby('AIRLINE').aggregate({'CANCELLED':'sum'})
# Out:
#          CANCELLED
# AIRLINE
# AA             154
# AS               0
# B6               1
# DL              38
# EV             146
# F9              10
# HA               0
# MQ             152
# NK              25
# OO             142
# UA              93
# US              21
# VX               6
# WN              93

# %% [markdown]
# `-` 예제3: 항공사(AIRLINE)별로 비행취소율(CANCELLED)을 구하라. 비행취소율이 가장 높은 두개의 항공사는 어디인가?

# %%
df.groupby('AIRLINE').aggregate({'CANCELLED':'mean'})
# df.groupby('AIRLINE').aggregate({'CANCELLED':lambda x : sum(x)/len(x)})
# Out:
#          CANCELLED
# AIRLINE
# AA        0.017303
# AS        0.000000
# B6        0.001842
# DL        0.003585
# EV        0.024923
# F9        0.007593
# HA        0.000000
# MQ        0.043791
# NK        0.016491
# OO        0.021554
# UA        0.011935
# US        0.013003
# VX        0.006042
# WN        0.011048

# %% [markdown]
# `-` 예제4: 비행취소율이 가장 높은 두개의 항공사(AIRLINE)를 선택하라. 그 두 항공사에 대하여 요일별(WEEKDAY) 비행취소율(CANCELLED)을 조사하라.

# %%
df.groupby('AIRLINE').aggregate({'CANCELLED':'mean'})
# Out:
#          CANCELLED
# AIRLINE
# AA        0.017303
# AS        0.000000
# B6        0.001842
# DL        0.003585
# EV        0.024923
# F9        0.007593
# HA        0.000000
# MQ        0.043791
# NK        0.016491
# OO        0.021554
# UA        0.011935
# US        0.013003
# VX        0.006042
# WN        0.011048

# %% [markdown]
# MQ와 EV

# %% [markdown]
# `-` 예제5: 아래는 운행거리의 요약통계량이다.

# %%
df.DIST.describe()
# Out:
# count    58492.000000
# mean       872.900072
# std        624.996805
# min         67.000000
# 25%        391.000000
# 50%        690.000000
# 75%       1199.000000
# max       4502.000000
# Name: DIST, dtype: float64

# %% [markdown]
# 운행거리를 구간별로 `[-np.inf,391,690,1199,np.inf]`와 같이 나눈뒤 비행취소건수와 취소율을 구하여라.

# %%
_bin = [-np.inf,391,690,1199,np.inf]
df.assign(DIST2 = pd.cut(df.DIST,_bin)).groupby('DIST2').aggregate({'CANCELLED':['mean','sum']})
# Out:
#                 CANCELLED
#                      mean  sum
# DIST2
# (-inf, 391.0]    0.022659  334
# (391.0, 690.0]   0.013503  196
# (690.0, 1199.0]  0.013637  203
# (1199.0, inf]    0.010313  148

# %% [markdown]
# # Quiz: HRDataset_v14 자료분석

# %% [markdown]
# 아래의 코드를 활용하여 Kaggle의 [HRdataset](https://www.kaggle.com/datasets/rhuebner/human-resources-data-set)을 불러오라.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guebin/DV2022/master/posts/HRDataset_v14.csv')
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0              1       5            4                       0   62506  ...
# 1              5       3            3                       0  104437  ...
# 2              5       5            3                       0   64955  ...
# 3              1       5            3                       0   64991  ...
# 4              5       5            3                       0   50825  ...
# ..           ...     ...          ...                     ...     ...  ...
# 306            1       5            3                       0   65893  ...
# 307            5       5            1                       0   48513  ...
# 308            1       3            4                       0  220450  ...
# 309            1       3            3                       0   89292  ...
# 310            1       5            3                       0   45046  ...
#
#         ManagerName  ManagerID  RecruitmentSource PerformanceScore  \
# 0    Michael Albert       22.0           LinkedIn          Exceeds
# 1        Simon Roup        4.0             Indeed      Fully Meets
# 2    Kissy Sullivan       20.0           LinkedIn      Fully Meets
# 3      Elijiah Gray       16.0             Indeed      Fully Meets
# 4    Webster Butler       39.0      Google Search      Fully Meets
# ..              ...        ...                ...              ...
# 306  Kissy Sullivan       20.0           LinkedIn      Fully Meets
# 307  Brannon Miller       12.0      Google Search              PIP
# 308      Janet King        2.0  Employee Referral          Exceeds
# 309      Simon Roup        4.0  Employee Referral      Fully Meets
# 310   David Stanley       14.0           LinkedIn      Fully Meets
#
#      EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0                4.60               5                    0
# 1                4.96               3                    6
# 2                3.02               3                    0
# 3                4.84               5                    0
# 4                5.00               4                    0
# ..                ...             ...                  ...
# 306              4.07               4                    0
# 307              3.20               2                    0
# 308              4.60               5                    6
# 309              5.00               3                    5
# 310              4.50               5                    0
#
#     LastPerformanceReview_Date DaysLateLast30 Absences
# 0                    1/17/2019              0        1
# 1                    2/24/2016              0       17
# 2                    5/15/2012              0        3
# 3                     1/3/2019              0       15
# 4                     2/1/2016              0        2
# ..                         ...            ...      ...
# 306                  2/28/2019              0       13
# 307                   9/2/2015              5        4
# 308                  2/21/2019              0       16
# 309                   2/1/2019              0       11
# 310                  1/30/2019              0        2
#
# [311 rows x 36 columns]

# %% [markdown]
# 다음을 읽고 참 거짓을 판단하여라.
#
# `1`. 근무인원수가 가장 많은 인종(RaceDesc)은 'White'이며 이는 'Asian'인종과 'Black or African American'의 합보다 많다.

# %%
df.groupby('RaceDesc').aggregate({'RaceDesc': 'count'})
# Out:
#                                   RaceDesc
# RaceDesc
# American Indian or Alaska Native         3
# Asian                                   29
# Black or African American               80
# Hispanic                                 1
# Two or more races                       11
# White                                  187

# %% [markdown]
# `2`. 'RaceDesc==White'의 성별(Sex)임금차이는 2000이상이다.

# %%
df.query("RaceDesc == 'White'").groupby('Sex').aggregate({'Salary': 'mean'})
# Out:
#            Salary
# Sex
# F    68846.519231
# M    65334.132530

# %% [markdown]
# `3`. 퇴직한사람(Termd==1)은 모두 104명이며 백인여성의 퇴직자수가 가장 많다.

# %%
print(len(df.query("Termd == 1")))
df.query("Termd == 1").groupby("RaceDesc").aggregate({"RaceDesc":"count"})
# Out:
# 104
#                            RaceDesc
# RaceDesc
# Asian                             9
# Black or African American        29
# Two or more races                 3
# White                            63

# %% [markdown]
# `4`. 퇴직한사람중 아시아인의 비율은 10%가 넘지 않는다.

# %%
df.query("Termd == 1").groupby("RaceDesc").aggregate({"RaceDesc":lambda x : len(x)/len(df.query("Termd == 1"))})
# Out:
#                            RaceDesc
# RaceDesc
# Asian                      0.086538
# Black or African American  0.278846
# Two or more races          0.028846
# White                      0.605769

# %% [markdown]
# 아래를 조사하라.

# %% [markdown]
# `5`. [성별(Sex), 결혼유무(MarriedID)] 별 연봉(Salary)의 평균을 조사하라. 어떠한 그룹이 가장 평균연봉이 적은가?

# %%
df.groupby(["Sex", "MarriedID"]).aggregate({"Salary":"mean"})
# Out:
#                      Salary
# Sex MarriedID
# F   0          66504.394231
#     1          69638.986111
# M   0          70967.939759
#     1          70089.038462

# %% [markdown]
# `6`. [성별(Sex), 인종별(RaceDesc)] 별 연봉(Salary)의 중앙값('median')을 조사하라. 연봉의 중앙값이 가장 높은 그룹은 무엇인가?

# %%
df.groupby(["Sex", "RaceDesc"]).aggregate({"Salary":"median"})
# Out:
#                                        Salary
# Sex RaceDesc
# F   American Indian or Alaska Native  63436.5
#     Asian                             63676.0
#     Black or African American         61584.0
#     Two or more races                 57837.0
#     White                             62405.0
# M   American Indian or Alaska Native  70545.0
#     Asian                             64731.0
#     Black or African American         71339.0
#     Hispanic                          83667.0
#     Two or more races                 61568.0
#     White                             61809.0

# %% [markdown]
# `7`. [성별(Sex), 인종별(RaceDesc)] 별 연봉(Salary)의 중앙값('median')과 근무인원수를 함께 조사하라. 연봉의 중앙값이 가장 높은 그룹이 혜택을 받는 그룹이라고 느껴지는가?

# %%
df.groupby(["Sex", "RaceDesc"]).aggregate({"Salary":["median","count"]})
# Out:
#                                        Salary
#                                        median count
# Sex RaceDesc
# F   American Indian or Alaska Native  63436.5     2
#     Asian                             63676.0    17
#     Black or African American         61584.0    47
#     Two or more races                 57837.0     6
#     White                             62405.0   104
# M   American Indian or Alaska Native  70545.0     1
#     Asian                             64731.0    12
#     Black or African American         71339.0    33
#     Hispanic                          83667.0     1
#     Two or more races                 61568.0     5
#     White                             61809.0    83
